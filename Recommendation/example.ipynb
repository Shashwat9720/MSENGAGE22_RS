# %%
import pandas as pd
import numpy as np
import Recommenders as Recommender

# %%
df_1 = pd.read_csv('triplets_file.csv')
df_1.head(10)
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODDNQT12A6D4F5F7E             5
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODXRTY12AB0180F3B             1
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFGUAY12AB017B0A8             1
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFRQTD12A81C233C0             1
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOHQWYZ12A6D4FA701             1

# %%
df_2 = pd.read_csv('song_data.csv')
df_2.head(10)
# Out:
#               song_id                                              title  \
# 0  SOQMMHC12AB0180CB8                                       Silent Night
# 1  SOVFVAK12A8C1350D9                                        Tanssi vaan
# 2  SOGTUKN12AB017F4F1                                  No One Could Ever
# 3  SOBNYVR12A8C13558C                                      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF                                   Tangle Of Aspens
# 5  SOZVAPQ12A8C13B63C  Symphony No. 1 G minor "Sinfonie Serieuse"/All...
# 6  SOQVRHI12A6D4FB2D7                                   We Have Got Love
# 7  SOEYRFT12AB018936C                                  2 Da Beat Ch'yall
# 8  SOPMIYT12A6D4F851E                                            Goodbye
# 9  SOJCFMH12A8C13B0C2                         Mama_ mama can't you see ?
#
#                                 release  \
# 0                 Monster Ballads X-Mas
# 1                           Karkuteillä
# ...

# %%
final_df = df_1.merge(df_2, on = 'song_id')
final_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  7c86176941718984fed11b7c0674ff04c029b480  SOAKIMP12A8C130995             1
# 2  76235885b32c4e8c82760c340dc54f9b608d7d7e  SOAKIMP12A8C130995             3
# 3  250c0fa2a77bc6695046e7c47882ecd85c42d748  SOAKIMP12A8C130995             1
# 4  3f73f44560e822344b0fb7c6b463869743eb9860  SOAKIMP12A8C130995             6
#
#       title             release   artist_name  year
# 0  The Cove  Thicker Than Water  Jack Johnson     0
# 1  The Cove  Thicker Than Water  Jack Johnson     0
# 2  The Cove  Thicker Than Water  Jack Johnson     0
# 3  The Cove  Thicker Than Water  Jack Johnson     0
# 4  The Cove  Thicker Than Water  Jack Johnson     0

# %%
final_df['song'] = final_df['title']+' - '+final_df['artist_name']
final_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  7c86176941718984fed11b7c0674ff04c029b480  SOAKIMP12A8C130995             1
# 2  76235885b32c4e8c82760c340dc54f9b608d7d7e  SOAKIMP12A8C130995             3
# 3  250c0fa2a77bc6695046e7c47882ecd85c42d748  SOAKIMP12A8C130995             1
# 4  3f73f44560e822344b0fb7c6b463869743eb9860  SOAKIMP12A8C130995             6
#
#       title             release   artist_name  year                     song
# 0  The Cove  Thicker Than Water  Jack Johnson     0  The Cove - Jack Johnson
# 1  The Cove  Thicker Than Water  Jack Johnson     0  The Cove - Jack Johnson
# 2  The Cove  Thicker Than Water  Jack Johnson     0  The Cove - Jack Johnson
# 3  The Cove  Thicker Than Water  Jack Johnson     0  The Cove - Jack Johnson
# 4  The Cove  Thicker Than Water  Jack Johnson     0  The Cove - Jack Johnson

# %%
# song_grouped = final_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
# song_grouped.head()
# Out:
#                                                 song  listen_count
# 0  #!*@ You Tonight [Featuring R. Kelly] (Explici...            78
# 1                           #40 - DAVE MATTHEWS BAND           338
# 2                                & Down - Boys Noize           373
# 3                          ' Cello Song - Nick Drake           103
# 4                        '97 Bonnie & Clyde - Eminem            93

# %%
# grouped_sum = song_grouped['listen_count'].sum()
# song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
# song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count  \
# 7150                           Sehr kosmisch - Harmonia          8277
# 9168                       Use Somebody - Kings Of Leon          7952
# 9112                                       Undo - Björk          7032
# 2075  Dog Days Are Over (Radio Edit) - Florence + Th...          6949
# 9909                     You're The One - Dwight Yoakam          6412
# ...                                                 ...           ...
# 3536              Historia Del Portero - Ricardo Arjona            51
# 7093                          Scared - Three Days Grace            51
# 2154                    Don´t Leave Me Now - Amparanoia            50
# 3000              Ghosts (Toxic Avenger Mix) - Ladytron            48
# 5830                       No Creo En El Jamas - Juanes            48
#
#       percentage
# 7150    0.396608
# 9168    0.381035
# 9112    0.336952
# 2075    0.332975
# 9909    0.307243
# ...

# %%
pr = Recommender.pop_recommend()
pr.create(final_df, 'user_id', 'song')

pr.recommend(final_df['user_id'][3])
# Out:
#                                        user_id  \
# 7150  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 9168  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 9112  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 2075  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 9909  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 6795  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 7138  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 9782  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 7564  250c0fa2a77bc6695046e7c47882ecd85c42d748
# 3623  250c0fa2a77bc6695046e7c47882ecd85c42d748
#
#                                                    song  score  Rank
# 7150                           Sehr kosmisch - Harmonia   8277   1.0
# 9168                       Use Somebody - Kings Of Leon   7952   2.0
# 9112                                       Undo - Björk   7032   3.0
# 2075  Dog Days Are Over (Radio Edit) - Florence + Th...   6949   4.0
# 9909                     You're The One - Dwight Yoakam   6412   5.0
# ...
